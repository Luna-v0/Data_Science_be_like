# %%
import numpy as np
from matplotlib import pyplot as plt
from jax import numpy as jnp
from jax import jit
import jax

# %%
np.random.randint(0,100,100)
# Out:
# array([17, 39, 87, 44, 99, 66,  7, 56, 61, 31, 38, 18, 58, 28, 75, 42, 86,
#        39, 24,  3,  7, 54, 91, 34,  2, 17, 15, 65, 13, 40, 48, 81, 63, 36,
#        99, 86, 64, 31, 67, 14, 13, 65, 43, 95, 93, 13,  3, 30, 93, 93,  4,
#        70, 91, 36, 24, 19, 41,  8, 31, 66, 99, 67, 53, 21, 49, 62, 95, 94,
#        43, 46, 78, 13, 89, 93, 63, 76, 20, 17, 66, 27, 90, 33,  3, 73, 51,
#         1,  6, 19, 34, 11, 79, 16, 13, 91,  0, 67, 80, 82, 18, 56])

# %%
# Out:
# Array([0.8467145 , 0.21632263, 0.976276  , 0.9686373 , 0.36718464,
#        0.43550503, 0.6337106 , 0.91239923, 0.725004  , 0.6787026 ,
#        0.9998492 , 0.6001368 , 0.49308124, 0.97502875, 0.99478394,
#        0.38503268, 0.543605  , 0.25376064, 0.22797567, 0.6021099 ,
#        0.6238778 , 0.85875994, 0.3089056 , 0.38921398, 0.40791592,
#        0.15976833, 0.4822319 , 0.37940705, 0.02161233, 0.03940953,
#        0.09389906, 0.66694003, 0.693659  , 0.89270115, 0.81599885,
#        0.08306546, 0.40376234, 0.7332988 , 0.01261359, 0.02965371,
#        0.77953213, 0.5987698 , 0.73000085, 0.7380641 , 0.29084566,
#        0.04798221, 0.4544821 , 0.51491016, 0.6871932 , 0.8777361 ,
#        0.23981732, 0.37887886, 0.33492115, 0.1895612 , 0.1836639 ,
#        0.15432478, 0.7648998 , 0.5392343 , 0.06531469, 0.5100734 ,
#        0.8386122 , 0.2895192 , 0.5028767 , 0.22214444, 0.8544795 ,
#        0.9510659 , 0.94431937, 0.25215408, 0.84981424, 0.7869258 ,
# ...
