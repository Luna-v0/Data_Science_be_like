# %% [markdown]
# # Basic HuggingFace
#
# Exploring a pix2text model, a model from taking pictures and generating latex code

# %%
# !pwd
# Out:
# /mnt/hdd1/Repos/ds_be_like/code/notebooks

# %%
#! pip install transformers>=4.37.0 pillow optimum[onnxruntime]
from PIL import Image
from transformers import TrOCRProcessor
from optimum.onnxruntime import ORTModelForVision2Seq

processor = TrOCRProcessor.from_pretrained('breezedeus/pix2text-mfr')
model = ORTModelForVision2Seq.from_pretrained('breezedeus/pix2text-mfr', use_cache=True)

image_fps = [
    '../../image.png'
]
images = [Image.open(fp).convert('RGB') for fp in image_fps]
pixel_values = processor(images=images, return_tensors="pt").pixel_values
generated_ids = model.generate(pixel_values)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)
print(f'generated_ids: {generated_ids}, \ngenerated text: {generated_text}')
# Out:
# generated_ids: tensor([[  2,  74, 267, 282, 266, 270, 263, 357, 264, 262, 281, 270, 268, 261,
#          265, 262, 284, 261, 435, 264, 262, 281, 261, 282, 264, 262, 281, 261,
#          274, 345,   2]]),
# generated text: ['f ( x ) = \\sum _ { i = 1 } ^ { n } w _ { i } x _ { i } + b']
