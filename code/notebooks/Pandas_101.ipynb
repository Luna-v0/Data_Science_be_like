# %% [markdown]
# # Objetos do Pandas

# %% [markdown]
# ## Data Frame
#
# Data frames são tabelas que nem de um banco de dados ou arquivo excel ou ate mesmo um dicionario de listas

# %%
import pandas as pd

pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ## Series
#
# Series seria algo como um vetor

# %%
pd.Series(["World","Mom"], index=["Hello","world"], name="Test")
# Out:
# Hello    World
# world      Mom
# Name: Test, dtype: object

# %% [markdown]
# ## Leitura de arquivos

# %%
digimons = pd.read_csv("data/digimons/digimons.csv")
print(f"(i,j): {digimons.shape}")

# save file is
digimons.to_csv("data/digimons/digimons2.csv", index=False)
digimons.head()
# Out:
# (i,j): (249, 13)
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86

# %% [markdown]
# ### Para ler uma coluna especifica podemos usar tres formas

# %%
digimons.Digimon
digimons['Digimon']
digimons.iloc[:,1]
# Out:
# 0                Kuramon
# 1                Pabumon
# 2                Punimon
# 3                Botamon
# 4                Poyomon
#              ...
# 244           Valkyrimon
# 245      ShineGreymon BM
# 246    MirageGaogamon BM
# 247           Ravemon BM
# 248           Rosemon BM
# Name: Digimon, Length: 249, dtype: object

# %% [markdown]
# #### Para ler multiplas colunas ao mesmo tempo podemos usar o operador de python : ou arrays

# %%
digimons.iloc[[0,1,2],1]
digimons.iloc[0:3,1]
# Out:
# 0    Kuramon
# 1    Pabumon
# 2    Punimon
# Name: Digimon, dtype: object

# %% [markdown]
# #### Para ler linhas por nome podemos usar o loc

# %%
digimons.loc[:6,'Digimon']
# Out:
# 0    Kuramon
# 1    Pabumon
# 2    Punimon
# 3    Botamon
# 4    Poyomon
# 5    Koromon
# 6    Tanemon
# Name: Digimon, dtype: object

# %% [markdown]
# ### Podemos tambem ler linhas validando uma condição

# %%
digimons.Digimon == 'Kuramon'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# Name: Digimon, Length: 249, dtype: bool

# %% [markdown]
# ### Para ler uma celula especifica podemos usar

# %%
digimons['Digimon'][0]
# Out:
# 'Kuramon'

# %% [markdown]
# ### Para ler uma linha especifica podemos usar

# %%
digimons.iloc[0]
# Out:
# Number               1
# Digimon        Kuramon
# Stage             Baby
# Type              Free
# Attribute      Neutral
# Memory               2
# Equip Slots          0
# Lv 50 HP           590
# Lv50 SP             77
# Lv50 Atk            79
# Lv50 Def            69
# Lv50 Int            68
# Lv50 Spd            95
# Name: 0, dtype: object

# %% [markdown]
# #### Usando condicional para ler linhas

# %%
digimons.loc[(digimons.Digimon == 'MetalGarurumon') | (digimons.Digimon == 'MetalGreymon')]
# Out:
#      Number         Digimon     Stage     Type Attribute  Memory  Equip Slots  \
# 151     152    MetalGreymon  Ultimate  Vaccine      Fire      14            1
# 222     223  MetalGarurumon      Mega     Data     Water      18            3
#
#      Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 151      1530       84       168       148        80       113
# 222      1140      143       154       129       129       178

# %%
digimons.loc[digimons.Stage.isin(['Ultimate','Mega'])]
# Out:
#      Number            Digimon     Stage     Type Attribute  Memory  \
# 108     109    MegaKabuterimon  Ultimate  Vaccine     Plant      12
# 109     110          Antylamon  Ultimate     Data   Neutral      12
# 110     111           Andromon  Ultimate  Vaccine  Electric      12
# 111     112          Meteormon  Ultimate     Data     Earth      12
# 112     113           Infermon  Ultimate     Free      Dark      14
# ..      ...                ...       ...      ...       ...     ...
# 244     245         Valkyrimon      Mega     Free      Wind      18
# 245     246    ShineGreymon BM      Mega  Vaccine      Fire      22
# 246     247  MirageGaogamon BM      Mega     Data     Light      20
# 247     248         Ravemon BM      Mega  Vaccine      Wind      20
# 248     249         Rosemon BM      Mega     Data     Plant      20
#
#      Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# ...

# %%
digimons.loc[digimons.Attribute.notnull()]
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %% [markdown]
# ### Mudando o Indice da tabela

# %%
digimons.set_index('Digimon')
# Out:
#                    Number Stage     Type Attribute  Memory  Equip Slots  \
# Digimon
# Kuramon                 1  Baby     Free   Neutral       2            0
# Pabumon                 2  Baby     Free   Neutral       2            0
# Punimon                 3  Baby     Free   Neutral       2            0
# Botamon                 4  Baby     Free   Neutral       2            0
# Poyomon                 5  Baby     Free   Neutral       2            0
# ...                   ...   ...      ...       ...     ...          ...
# Valkyrimon            245  Mega     Free      Wind      18            3
# ShineGreymon BM       246  Mega  Vaccine      Fire      22            2
# MirageGaogamon BM     247  Mega     Data     Light      20            2
# Ravemon BM            248  Mega  Vaccine      Wind      20            2
# Rosemon BM            249  Mega     Data     Plant      20            2
#
#                    Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# Digimon
# ...

# %% [markdown]
# ### Alterando dados

# %%
digimons['Novo_index'] = [digimon for digimon in enumerate(digimons['Digimon'])]
digimons['Novo_index']
# Out:
# 0                  (0, Kuramon)
# 1                  (1, Pabumon)
# 2                  (2, Punimon)
# 3                  (3, Botamon)
# 4                  (4, Poyomon)
#                  ...
# 244           (244, Valkyrimon)
# 245      (245, ShineGreymon BM)
# 246    (246, MirageGaogamon BM)
# 247           (247, Ravemon BM)
# 248           (248, Rosemon BM)
# Name: Novo_index, Length: 249, dtype: object

# %% [markdown]
# ### Função de Sumario

# %%
digimons['Memory'].describe()
# Out:
# count    249.000000
# mean      11.987952
# std        6.616501
# min        2.000000
# 25%        6.000000
# 50%       12.000000
# 75%       18.000000
# max       25.000000
# Name: Memory, dtype: float64

# %%
digimons['Attribute'].describe()
# Out:
# count      249
# unique       9
# top       Dark
# freq        37
# Name: Attribute, dtype: object

# %%
digimons['Lv 50 HP'].mean()
# Out:
# 1210.8835341365461

# %%
digimons['Attribute'].unique()
# Out:
# array(['Neutral', 'Fire', 'Plant', 'Earth', 'Dark', 'Light', 'Water',
#        'Wind', 'Electric'], dtype=object)

# %%
digimons['Attribute'].value_counts()
# Out:
# Attribute
# Dark        37
# Fire        33
# Light       29
# Neutral     28
# Plant       25
# Electric    25
# Earth       24
# Water       24
# Wind        24
# Name: count, dtype: int64

# %%
# Gera novo DS
digimons['Lv 50 HP'].map(lambda hp: hp + digimons['Lv 50 HP'].max())
# Out:
# 0      2670
# 1      3030
# 2      2950
# 3      2770
# 4      2620
#        ...
# 244    3410
# 245    4060
# 246    3520
# 247    3120
# 248    3560
# Name: Lv 50 HP, Length: 249, dtype: int64

# %%
def balance(digimon):
    digimon['Lv50 Atk'] = digimon['Lv50 Def'] + digimon['Lv50 Spd']
    return digimon

digimons.apply(balance,axis='columns')
# geram novo DS
# Out:
# 79
# 76
# 97
# 77
# 54
# 109
# 85
# 107
# 108
# 76
# 54
# 60
# 82
# 54
# 82
# 79
# 131
# 124
# 67
# 83
# 82
# 52
# 118
# 123
# 94
# 99
# 133
# 53
# 123
# 93
# 115
# 93
# 53
# 69
# 84
# 86
# 72
# 128
# 66
# 79
# 118
# 103
# 89
# 85
# 94
# 130
# 59
# 61
# 99
# 87
# 59
# 89
# 103
# 92
# 140
# 109
# 89
# 118
# 74
# 109
# 104
# 128
# 155
# 108
# 109
# 108
# 79
# 109
# 99
# 109
# 59
# 143
# 153
# 148
# 153
# 64
# 153
# 68
# 104
# 59
# 131
# 64
# 64
# 143
# 89
# 104
# 143
# 64
# 113
# 148
# 69
# 133
# 108
# 138
# 108
# 84
# 94
# 64
# 138
# 79
# 84
# 113
# 104
# 138
# 103
# 143
# 94
# 133
# 94
# 124
# 133
# 123
# 198
# 148
# 163
# 104
# 69
# 158
# 124
# 137
# 129
# 163
# 173
# 84
# 113
# 119
# 122
# 203
# 150
# 69
# 124
# 128
# 183
# 113
# 161
# 135
# 74
# 139
# 124
# 123
# 104
# 89
# 148
# 64
# 123
# 98
# 158
# 111
# 86
# 158
# 178
# 168
# 173
# 130
# 123
# 128
# 119
# 178
# 69
# 114
# 74
# 163
# 99
# 178
# 183
# 69
# 158
# 188
# 74
# 139
# 198
# 158
# 193
# 193
# 174
# 104
# 203
# 178
# ...

# %%
digimons['Digimon'] + " : " + digimons["Attribute"]
# Out:
# 0              Kuramon : Neutral
# 1              Pabumon : Neutral
# 2              Punimon : Neutral
# 3              Botamon : Neutral
# 4              Poyomon : Neutral
#                  ...
# 244            Valkyrimon : Wind
# 245       ShineGreymon BM : Fire
# 246    MirageGaogamon BM : Light
# 247            Ravemon BM : Wind
# 248           Rosemon BM : Plant
# Length: 249, dtype: object

# %%
def isBM(digimon):
    digimon['BM'] = 'BM' in digimon['Digimon']
    return digimon

digimons.apply(isBM,axis='columns')
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %%
digimons.groupby('Memory')["Memory"].count()
# Out:
# Memory
# 2      5
# 3     11
# 4     19
# 5     18
# 6     26
# 8     29
# 10     5
# 12    35
# 14    18
# 16     3
# 18    33
# 20    17
# 22    22
# 25     8
# Name: Memory, dtype: int64

# %%
digimons.groupby('Memory').agg({'Memory': ['count', 'min', 'max']})
# Out:
#        Memory
#         count min max
# Memory
# 2           5   2   2
# 3          11   3   3
# 4          19   4   4
# 5          18   5   5
# 6          26   6   6
# 8          29   8   8
# 10          5  10  10
# 12         35  12  12
# 14         18  14  14
# 16          3  16  16
# 18         33  18  18
# 20         17  20  20
# 22         22  22  22
# 25          8  25  25

# %%
digimons.groupby('Stage').apply(lambda digimon: digimon['Digimon'].iloc[0:3])
# Out:
# Stage
# Armor        237          Flamedramon
#              238             Magnamon
#              239     Rapidmon (Armor)
# Baby         0                Kuramon
#              1                Pabumon
#              2                Punimon
# Champion     54            IceDevimon
#              55             Aquilamon
#              56             Ankylomon
# In-Training  5                Koromon
#              6                Tanemon
#              7               Tsunomon
# Mega         166             Alphamon
#              167     UlforceVeedramon
#              168               Ebemon
# Rookie       16                Agumon
#              17          Agumon (Blk)
#              18          Armadillomon
# Ultimate     108      MegaKabuterimon
#              109            Antylamon
#              110             Andromon
# Ultra        232    Imperialdramon PM
#              233              Omnimon
#              234        Omnimon Zwart
# Name: Digimon, dtype: object

# %%
digimons.groupby(['Stage','Attribute']).apply(lambda digimon: digimon['Digimon'].iloc[0:3])
# Out:
# Stage  Attribute
# Armor  Earth      238             Magnamon
#        Fire       237          Flamedramon
#        Light      239     Rapidmon (Armor)
# Baby   Neutral    0                Kuramon
#                   1                Pabumon
#                                ...
# Ultra  Dark       235         Belphemon RM
#                   236           Lucemon SM
#        Light      232    Imperialdramon PM
#                   233              Omnimon
#        Neutral    243             Chaosmon
# Name: Digimon, Length: 130, dtype: object

# %%
digimons.groupby(['Stage','Type'])['Digimon'].agg([len])
# Out:
#                      len
# Stage       Type
# Armor       Free       2
#             Vaccine    1
# Baby        Free       5
# Champion    Data      12
#             Free       5
#             Vaccine   15
#             Virus     22
# In-Training Free      11
# Mega        Data      21
#             Free       5
#             Vaccine   21
#             Virus     27
# Rookie      Data      11
#             Free       5
#             Vaccine   11
#             Virus     11
# Ultimate    Data      16
#             Free       4
#             Vaccine   18
#             Virus     20
# Ultra       Vaccine    4
#             Virus      2

# %%
digimons.sort_values(by='Lv50 Atk', ascending=False)
# Out:
#      Number       Digimon        Stage     Type Attribute  Memory  \
# 243     244      Chaosmon        Ultra  Vaccine   Neutral      25
# 235     236  Belphemon RM        Ultra    Virus      Dark      25
# 195     196    Diaboromon         Mega     Free      Dark      20
# 241     242  Beelzemon BM         Mega    Virus      Dark      25
# 211     212     Beelzemon         Mega    Virus      Dark      22
# ..      ...           ...          ...      ...       ...     ...
# 13       14       Bukamon  In-Training     Free     Water       3
# 10       11      Nyaromon  In-Training     Free     Light       3
# 27       28       Kudamon       Rookie  Vaccine     Light       5
# 32       33      Syakomon       Rookie    Virus     Water       4
# 21       22      Otamamon       Rookie    Virus     Water       4
#
#      Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 243            2      1080      129       318        94        89       188
# ...

# %%
digimons.sort_values(by=['Lv50 Atk','Lv50 Def'], ascending=[False,True])
# Out:
#      Number       Digimon        Stage     Type Attribute  Memory  \
# 243     244      Chaosmon        Ultra  Vaccine   Neutral      25
# 235     236  Belphemon RM        Ultra    Virus      Dark      25
# 195     196    Diaboromon         Mega     Free      Dark      20
# 241     242  Beelzemon BM         Mega    Virus      Dark      25
# 184     185   SaberLeomon         Mega     Data      Wind      18
# ..      ...           ...          ...      ...       ...     ...
# 10       11      Nyaromon  In-Training     Free     Light       3
# 13       14       Bukamon  In-Training     Free     Water       3
# 27       28       Kudamon       Rookie  Vaccine     Light       5
# 32       33      Syakomon       Rookie    Virus     Water       4
# 21       22      Otamamon       Rookie    Virus     Water       4
#
#      Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 243            2      1080      129       318        94        89       188
# ...

# %%
digimons.sort_index()
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %%
digimons.dtypes
# Out:
# Number          int64
# Digimon        object
# Stage          object
# Type           object
# Attribute      object
# Memory          int64
# Equip Slots     int64
# Lv 50 HP        int64
# Lv50 SP         int64
# Lv50 Atk        int64
# Lv50 Def        int64
# Lv50 Int        int64
# Lv50 Spd        int64
# dtype: object

# %%
digimons['Lv50 Atk'].astype('float64')
# Out:
# 0       79.0
# 1       76.0
# 2       97.0
# 3       77.0
# 4       54.0
#        ...
# 244    148.0
# 245    228.0
# 246    178.0
# 247    149.0
# 248    149.0
# Name: Lv50 Atk, Length: 249, dtype: float64

# %%
digimons.index.dtype
# Out:
# dtype('int64')

# %%
digimons.rename(columns={'Digimon': 'name'})
# Out:
#      Number               name Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %%
digimons.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Number            Digimon Stage     Type Attribute  Memory  \
# firstEntry        1            Kuramon  Baby     Free   Neutral       2
# secondEntry       2            Pabumon  Baby     Free   Neutral       2
# 2                 3            Punimon  Baby     Free   Neutral       2
# 3                 4            Botamon  Baby     Free   Neutral       2
# 4                 5            Poyomon  Baby     Free   Neutral       2
# ...             ...                ...   ...      ...       ...     ...
# 244             245         Valkyrimon  Mega     Free      Wind      18
# 245             246    ShineGreymon BM  Mega  Vaccine      Fire      22
# 246             247  MirageGaogamon BM  Mega     Data     Light      20
# 247             248         Ravemon BM  Mega  Vaccine      Wind      20
# 248             249         Rosemon BM  Mega     Data     Plant      20
#
#              Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  \
# ...

# %%
digimons.rename_axis("id", axis='rows').rename_axis("features", axis='columns') # type: ignore
# Out:
# features  Number            Digimon Stage     Type Attribute  Memory  \
# id
# 0              1            Kuramon  Baby     Free   Neutral       2
# 1              2            Pabumon  Baby     Free   Neutral       2
# 2              3            Punimon  Baby     Free   Neutral       2
# 3              4            Botamon  Baby     Free   Neutral       2
# 4              5            Poyomon  Baby     Free   Neutral       2
# ..           ...                ...   ...      ...       ...     ...
# 244          245         Valkyrimon  Mega     Free      Wind      18
# 245          246    ShineGreymon BM  Mega  Vaccine      Fire      22
# 246          247  MirageGaogamon BM  Mega     Data     Light      20
# 247          248         Ravemon BM  Mega  Vaccine      Wind      20
# 248          249         Rosemon BM  Mega     Data     Plant      20
#
# features  Equip Slots  Lv 50 HP  Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  \
# id
# ...

# %%
moves = pd.read_csv("data/digimons/moves.csv")
pd.concat([digimons,moves],axis='columns')
# Out:
#      Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1.0  Kuramon  Baby  Free   Neutral     2.0          0.0     590.0
# 1       2.0  Pabumon  Baby  Free   Neutral     2.0          0.0     950.0
# 2       3.0  Punimon  Baby  Free   Neutral     2.0          0.0     870.0
# 3       4.0  Botamon  Baby  Free   Neutral     2.0          0.0     690.0
# 4       5.0  Poyomon  Baby  Free   Neutral     2.0          0.0     540.0
# ..      ...      ...   ...   ...       ...     ...          ...       ...
# 382     NaN      NaN   NaN   NaN       NaN     NaN          NaN       NaN
# 383     NaN      NaN   NaN   NaN       NaN     NaN          NaN       NaN
# 384     NaN      NaN   NaN   NaN       NaN     NaN          NaN       NaN
# 385     NaN      NaN   NaN   NaN       NaN     NaN          NaN       NaN
# 386     NaN      NaN   NaN   NaN       NaN     NaN          NaN       NaN
#
#      Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd             Move  \
# ...

# %%
left = digimons.set_index(['Memory'])
right = moves.set_index(['SP Cost'])

# left.join(right) not joinable
